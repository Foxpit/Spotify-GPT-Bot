# %%
# import packages
# %pip install spotipy
# %pip install openai
# Out:
# Requirement already satisfied: spotipy in /Users/hugo/miniconda3/lib/python3.10/site-packages (2.23.0)
# Requirement already satisfied: six>=1.15.0 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: redis>=3.5.3 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from spotipy) (4.5.5)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from spotipy) (1.26.14)
# Requirement already satisfied: async-timeout>=4.0.2 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: openai in /Users/hugo/miniconda3/lib/python3.10/site-packages (0.27.7)
# Requirement already satisfied: tqdm in /Users/hugo/miniconda3/lib/python3.10/site-packages (from openai) (4.64.1)
# Requirement already satisfied: requests>=2.20 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from openai) (2.28.1)
# Requirement already satisfied: aiohttp in /Users/hugo/miniconda3/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hugo/miniconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)

# %%
import os
import getpass 
import openai
import spotipy
import random
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
from random import sample


# # Get OpenAI API key
# openai.api_key = getpass("Please enter your OpenAI API key: ")

# def define_spotify():
#     print("1: Enter your Spotify API key\n2: Enter your Spotify id or username")
#     spotify_option = input("Input (1 or 2): ")

#     if spotify_option not in ['1', '2']:
#         print("Must input either 1 or 2")
#         return define_spotify()

#     if spotify_option == '1':
#         return getpass("Please enter your Spotify API key: ")
    
#     elif spotify_option == '2':
#         print("1: Spotify ID\n2:  Enter your username")
#         spotify_optionUorC = input("Input (1 or 2): ")
        

#         if spotify_optionUorC not in ['1', '2']:
#             print("Must input either 1 or 2")
#             return define_spotify()
        
#         if spotify_optionUorC == '1':
#             username = input("Username: ")
#             scope = "user-library-read playlist-modify-public"


#         if spotify_optionUorC == '2':
#             clientID = input("ClientID: ")
#             scope = "user-library-read playlist-modify-public"
#             os.environ["SPOTIPY_CLIENT_SECRET"] = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, client_id=clientID ,open_browser=True,))



# spotify = define_spotify()


# Get OpenAI API key
openai.api_key = getpass.getpass("Please enter your OpenAI API key: ")

def define_spotify():
    print("1: Enter your Spotify API details\n2: Log in to your Spotify account")
    spotify_option = input("Input (1 or 2): ")

    if spotify_option not in ['1', '2']:
        print("Must input either 1 or 2")
        return define_spotify()

    if spotify_option == '1':
        client_id = getpass("Please enter your Spotify Client ID: ")
        client_secret = getpass("Please enter your Spotify Client Secret: ")
        auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

    elif spotify_option == '2':
        print("Please log in to your Spotify account.")
        scope = "playlist-read-private playlist-read-collaborative user-library-read playlist-modify-public playlist-modify-private"
        auth_manager = SpotifyOAuth(scope=scope, open_browser=True)

    return spotipy.Spotify(auth_manager=auth_manager)

spotify = define_spotify()
# Out:
# 1: Enter your Spotify API details
# 2: Log in to your Spotify account
# Please log in to your Spotify account.
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[11], line 71
#      67         auth_manager = SpotifyOAuth(scope=scope, open_browser=True)
#      69     return spotipy.Spotify(auth_manager=auth_manager)
# ---> 71 spotify = define_spotify()
#
# Cell In[11], line 67, in define_spotify()
#      65     print("Please log in to your Spotify account.")
#      66     scope = "playlist-read-private playlist-read-collaborative user-library-read playlist-modify-public playlist-modify-private"
# ---> 67     auth_manager = SpotifyOAuth(scope=scope, open_browser=True)
#      69 return spotipy.Spotify(auth_manager=auth_manager)
#
# File ~/miniconda3/lib/python3.10/site-packages/spotipy/oauth2.py:332, in SpotifyOAuth.__init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     303 """
#     304 Creates a SpotifyOAuth object
#     305
#    (...)
#     327                       (takes precedence over `cache_path` and `username`)
#     328 """
#     330 super(SpotifyOAuth, self).__init__(requests_session)
# --> 332 self.client_id = client_id
#     333 self.client_secret = client_secret
#     334 self.redirect_uri = redirect_uri
#
# File ~/miniconda3/lib/python3.10/site-packages/spotipy/oauth2.py:94, in SpotifyAuthBase.client_id(self, val)
#      92 @client_id.setter
#      93 def client_id(self, val):
# ---> 94     self._client_id = _ensure_value(val, "client_id")
#
# File ~/miniconda3/lib/python3.10/site-packages/spotipy/oauth2.py:70, in _ensure_value(value, env_key)
#      65 if _val is None:
#      66     msg = "No %s. Pass it or set a %s environment variable." % (
#      67         env_key,
#      68         env_val,
#      69     )
# ---> 70     raise SpotifyOauthError(msg)
#      71 return _val
#
# SpotifyOauthError: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.

# %%
def get_user_tracks():
    results = spotify.current_user_saved_tracks()
    return [track['track']['id'] for track in results['items']]

def get_related_tracks(user_tracks):
    related_tracks = []
    for track in user_tracks:
        related = spotify.artist_top_tracks(spotify.track(track)['artists'][0]['id'])
        related_tracks.extend([t['id'] for t in related['tracks']])
    return related_tracks

def gpt_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=60
    )
    return response.choices[0].text.strip()

def create_playlist(prompt):
    # Generate playlist name using GPT-4
    playlist_name = gpt_prompt(prompt)
    
    # Get user's tracks
    user_tracks = get_user_tracks()
    
    # Get related tracks
    related_tracks = get_related_tracks(user_tracks)
    
    # Get intersection of user's tracks and related tracks
    common_tracks = list(set(user_tracks) & set(related_tracks))
    
    # Create new playlist
    playlist = spotify.user_playlist_create(os.getenv("spotifyUSERNAME"), playlist_name)
    
    # Add half from user's tracks and half from related tracks
    half_length = len(common_tracks) // 2
    tracks_to_add = common_tracks[:half_length] + related_tracks[:half_length]
    
    # Add tracks to the playlist
    spotify.playlist_add_items(playlist['id'], tracks_to_add)

# Prompt for creating the playlist
prompt = "Create a playlist for coding and focusing."
create_playlist(prompt)
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[2], line 13
#      11 scope = "user-library-read playlist-modify-public"
#      12 username = os.getenv("SPOTIFY_USERNAME")
# ---> 13 spotify = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, username=username))
#      15 def get_user_tracks():
#      16     results = spotify.current_user_saved_tracks()
#
# File ~/miniconda3/lib/python3.10/site-packages/spotipy/oauth2.py:332, in SpotifyOAuth.__init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     303 """
#     304 Creates a SpotifyOAuth object
#     305
#    (...)
#     327                       (takes precedence over `cache_path` and `username`)
#     328 """
#     330 super(SpotifyOAuth, self).__init__(requests_session)
# --> 332 self.client_id = client_id
#     333 self.client_secret = client_secret
#     334 self.redirect_uri = redirect_uri
#
# File ~/miniconda3/lib/python3.10/site-packages/spotipy/oauth2.py:94, in SpotifyAuthBase.client_id(self, val)
#      92 @client_id.setter
#      93 def client_id(self, val):
# ---> 94     self._client_id = _ensure_value(val, "client_id")
#
# File ~/miniconda3/lib/python3.10/site-packages/spotipy/oauth2.py:70, in _ensure_value(value, env_key)
#      65 if _val is None:
#      66     msg = "No %s. Pass it or set a %s environment variable." % (
#      67         env_key,
#      68         env_val,
#      69     )
# ---> 70     raise SpotifyOauthError(msg)
#      71 return _val
#
# SpotifyOauthError: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
